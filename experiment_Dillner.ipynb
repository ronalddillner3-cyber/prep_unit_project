# %% [markdown]
# <img src="Logo.png" width="100" align="left"/>
#
# # <center> Preparatory Unit project:</center>
#
#
#
# Congratulations on finishing the lessons content for this preparatory unit!!
#
# At this stage it's important to test your theoritical concepts from a practical side and that's exactely the goal of this project.

# %% [markdown]
# ## Some guidelines:
# 1. To run a cell you can use the shortcut use : Shift + Enter
#
# 2. Only sections mentioned as To-Do are the places where you should put in your own code other than that we do not recommend that you change the provided code.
#
# 3. You will be graded for the visibility of your code so make sure you respect the correct indentation and your code contains suitable variables names.
#
# 4. This notebook is designed in a sequential way so if you solve your project on different days make sure to run the previous cells before you can run the one you want.
#
# 5. Teacher assistants in th slack space remain available to answer any questions you might have.
#
# >Best of luck !

# %% [markdown]
# ## Project Sections:
# In this project you will have a chance to practice most of the important aspects we saw throughout The Preparatory Unit.
# This project is divided into 5 sections:
#
#
# 1. [Setting the environement](#set_env)
#
# 2. [Importing necessary tools](#importing)
#
# 3. [SQLite section](#sql)
#
# 4. [Data types section](#datatypes)
#
# 5. [Linear Algebra section](#algebra)

# %% [markdown]
# ### 1. Setting the environement:  <a id='set_env'></a>

# %%
# Make sure you have virtualenv installed
#!pip install --upgrade pip
###somehow I had problems to directly set up the virtual environment directly in colab/Jupyte under windows)
### I tested multiple ways but could not get it right
import sys
print(sys.executable)
import numpy as np
##here just a test to sea if numpy loaded correctly
arr = np.random.rand(3, 4)
print(arr)
#Here is a way how I would set up the venv in conda and then choose the environment in the settings
##or install venv outside jupyter in conda/ miniconda
#1.
#conda create --name myenv python=3.10
#2.
#conda activate myenv
#3.
#conda install jupyter ipykernel
#4
#python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"
#5.start jupyter notebook and change kernel  to new created environment under kernel->change kernel>-select created and active venv
#jupyter notebook
#6.###install packages from command line or conda
#conda install numpy pandas matplotlib
##or inside jupyter with
#!conda install -y numpy pandas matplotlib




##########################################################
###steps to create new environment in jupyter notebooks
# Create a new virtual environment named 'myenv'
#!python -m venv myenv
##activate created environment
#venv\Scripts\activate # On Windows
# Install ipykernel inside the virtual environment
#!myenv/Scripts/pip install ipykernel

# Register the new environment as a Jupyter kernel
#!myenv/Scripts/python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"

# Example: install numpy and pandas into the new environment
#!myenv/Scripts/pip install numpy pandas

    # Example output: /Users/youruser/anaconda3/envs/myenv/bin/python
    # OR: /usr/local/bin/python3

#!pip install --user virtualenv
########################################################to test!
#!python -m venv .venv
#!.\.venv\Scripts\python.exe -m pip install ipykernel pandas numpy matplotlib scipy
#!.\.venv\Scripts\python.exe -m ipykernel install --user --name myenv --display-name "Python myenv"
#############################
# Out:
# /usr/bin/python3
# [[0.11357853 0.26383179 0.6278676  0.93085687]
#  [0.30742916 0.97874263 0.73228919 0.29262819]
#  [0.28003409 0.37528831 0.40122561 0.56728086]]

# %%
# To-Do: create a virtual environement called myenv
##Here and below are some other ways I tried to set up the environment directly in jupyter
#but at some stage I always got error messages? Have you any tips or a way to
###set up an environment in jupyter under windows which is most stable
##I now failing to set up an venv can have many reasons so its not so easy to solve....
#!python -m venv myenv

# import os
# import subprocess
# import sys
# import shutil # Import shutil for rmtree

# venv_name = "myenv" # Changed from ".myenv" to "myenv"

# # Remove the virtual environment directory if it already exists
# if os.path.exists(venv_name):
#     print(os.path.abspath(venv_name))
#     shutil.rmtree(venv_name)
#     print(f"Removed existing virtual environment: {venv_name}")

# # Use '!' for direct shell execution, which can be more robust in Colab for venv creation
# !{sys.executable} -m venv {venv_name}
#print("Created:", os.path.abspath(venv_name))

# %%
# import os
# import subprocess

# venv_python = os.path.abspath(".venv\\Scripts\\python.exe")

# subprocess.run([venv_python, "-m", "pip", "install", "--upgrade", "pip"], check=True)
#subprocess.run([venv_python, "-m", "pip", "install", "numpy", "pandas", "matplotlib", "ipykernel","scipy"], check=True)

#print("Packages installed in", venv_python)

# %%
# packages = ["numpy", "pandas", "scikit-learn", "jupyterlab", "ipykernel","scipy","numpy"]
# subprocess.run([venv_python, "-m", "pip", "install"] + packages, check=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 packages = ["numpy", "pandas", "scikit-learn", "jupyterlab", "ipykernel","scipy","numpy"]
# ----> 2 subprocess.run([venv_python, "-m", "pip", "install"] + packages, check=True)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     551     kwargs['stdout'] = PIPE
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#     556         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...

# %%
#
# import os
# import subprocess
# import sys
# import urllib.request # To download get-pip.py

# #Where virtual environment was created above
# #'/content/myenv/bin/python3'
# venv_python = os.path.abspath('/content/myenv/bin/python3')
# #venv_python = os.path.abspath(".venv\\Scripts\\python.exe")
# kernel_name = "myenv"
# display_name = "Python myenv"

# # First, ensure pip is upgraded within the virtual environment
# # This might fix issues if ensurepip failed during venv creation
# try:
#     subprocess.run([venv_python, "-m", "pip", "install", "--upgrade", "pip"], check=True)
#     print(f"Pip upgraded successfully in {kernel_name}")
# except (subprocess.CalledProcessError, FileNotFoundError):
#     # If pip is not found or upgrade fails (meaning pip is likely broken/missing)
#     print(f"Attempting to bootstrap pip in {kernel_name}...")
#     get_pip_url = "https://bootstrap.pypa.io/get-pip.py"
#     get_pip_path = "get-pip.py"
#     try:
#         urllib.request.urlretrieve(get_pip_url, get_pip_path)
#         subprocess.run([venv_python, get_pip_path], check=True)
#         subprocess.run([venv_python, "-m", "pip", "install", "--upgrade", "pip"], check=True) # Try upgrading again
#         print(f"Pip bootstrapped and upgraded successfully in {kernel_name}")
#     except Exception as e:
#         print(f"Error bootstrapping pip in {kernel_name}: {e}")
#         # If bootstrapping fails, we can't proceed.
#         raise # Re-raise to indicate a critical failure

# # Install ipykernel into the virtual environment
# try:
#     subprocess.run([venv_python, "-m", "pip", "install", "ipykernel"], check=True)
#     print(f"ipykernel installed successfully in {kernel_name}")
# except subprocess.CalledProcessError as e:
#     print(f"Error installing ipykernel in {kernel_name}: {e}")
#     raise # Re-raise to indicate a critical failure

# subprocess.run([
#     venv_python, "-m", "ipykernel", "install",
#     "--user",
#     "--name", kernel_name,
#     "--display-name", display_name
# ], check=True)

# print("Kernel registered:", display_name)

# %%
# import sys
# print(sys.executable)

# %%
# Activate the environement
#!source myenv/bin/activate
#!myenv\Scripts\python -m pip install --upgrade pip
#!myenv\Scripts\python -m pip install ipykernel
#!.myenv\Scripts\python.exe -m pip install --upgrade pip

#"C:\Users\ronal\AppData\Local\Programs\Python\Python313\python.exe"
#venv\Scripts\activate

# %%
# Add this virtual environement to Jupyter notebook
# !pip install --user ipykernel
# !python -m ipykernel install --user --name=myenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.5 MB/s eta 0:00:00
# ...
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Installed kernelspec myenv in /root/.local/share/jupyter/kernels/myenv

# %%
# Install the necessary dependencies
#!pip install scipy
#!pip install numpy
###used here % instead of ! (!pip install numpy)- it ensures that pip is called within current kernel's environment
# %pip install numpy
# %pip install scipy
# %pip install matplotlib
#from google.colab import files
import sys
sys.path.append("/var")
####this command clones the github repository into the colab or jupyther folder structure so you can import python scripts
##and related classes and functions
# !git clone https://github.com/ronalddillner3-cyber/prep_unit_project.git

#sys.path.append("/content/prep_unit_project/")


#'C:/Users/ronal/Documents/codelabs_academy_tech_docs/github_clone/data'
# Out:
# ...
# Cloning into 'prep_unit_project'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 50 (delta 10), reused 3 (delta 3), pack-reused 17 (from 1)
# Receiving objects: 100% (50/50), 1.07 MiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %% [markdown]
# > Please check if you have sqlite installed on your device. For more informations head to the sql lesson

# %% [markdown]
# ### 2. Importing necessary tools:<a id='importing'></a>

# %%
#from data import database_manager as dm
import os
git_hub="https://github.com/ronalddillner3-cyber/prep_unit_project.git"

notebook_typ=[]
try:
    import google.colab
    print("Running in Google Colab")
    notebook_typ.append('google_colab')
except ImportError:
    print("Not in Google Colab")
    notebook_typ.append('jupyter_notebook')


repo_name=git_hub.split("/")[-1].replace(".git","")
if notebook_typ[0]=='google_colab':

  if os.getcwd().split('/')[-1]!=repo_name:
    os.chdir("./"+repo_name)
  else:
    print("already in current directory")
if notebook_typ[0]=="jupyter_notebook":
  ('no changes needed here')

###in google colab set the path to this so that the folders and python files are found
##not neccessary in jupyter after cloning


from data import database_manager_4 as dm
import utils_2 as utils
from matplotlib import pyplot
from linear_algebra import curve_fitting as cf
repo_name
os.getcwd()
# Out:
# Running in Google Colab
# already in current directory
# '/content/prep_unit_project'

# %% [markdown]
# ### 3. SQLite section : <a id='sql'></a>

# %%
# create a connection to the database
connection = dm.create_connection("./longley.db")

# To-Do : retrieve rows of the table
rows = dm.get_rows("longley.db", "SELECT * FROM longley")
print(rows)
# Out:
# ('83', '234.289', '235.6', '159', '107.608', '1947', '60.323')
# ('88.5', '259.426', '232.5', '145.6', '108.632', '1948', '61.122')
# ('88.2', '258.054', '368.2', '161.6', '109.773', '1949', '60.171')
# ('89.5', '284.599', '335.1', '165', '110.929', '1950', '61.187')
# ('96.2', '328.975', '209.9', '309.9', '112.075', '1951', '63.221')
# ('98.1', '346.999', '193.2', '359.4', '113.27', '1952', '63.639')
# ('99', '365.385', '187', '354.7', '115.094', '1953', '64.989')
# ('100', '363.112', '357.8', '335', '116.219', '1954', '63.761')
# ('101.2', '397.469', '290.4', '304.8', '117.388', '1955', '66.019')
# ('104.6', '419.18', '282.2', '285.7', '118.734', '1956', '67.857')
# ('108.4', '442.769', '293.6', '279.8', '120.445', '1957', '68.169')
# ('110.8', '444.546', '468.1', '263.7', '121.95', '1958', '66.513')
# ('112.6', '482.704', '381.3', '255.2', '123.366', '1959', '68.655')
# ('114.2', '502.601', '393.1', '251.4', '125.368', '1960', '69.564')
# ...

# %% [markdown]
# > Since at this stage we already retrieved our data it's more memory efficient to close the connection to our database.

# %%
#To-Do close connection using the close_connection function from the data_manager file (dm)
dm.close_connection(connection)

# %% [markdown]
# ### 4. Data types section : <a id='datatypes'></a>

# %% [markdown]
# Let's check the datatypes of the retrieved rows

# %%
connection = dm.create_connection("./longley.db")
select_all_rows = "SELECT * FROM longley"
#rows = dm.get_rows(connection, select_all_rows)
rows=dm.get_rows("./longley.db","SELECT * FROM longley")
# Out:
# ('83', '234.289', '235.6', '159', '107.608', '1947', '60.323')
# ('88.5', '259.426', '232.5', '145.6', '108.632', '1948', '61.122')
# ('88.2', '258.054', '368.2', '161.6', '109.773', '1949', '60.171')
# ('89.5', '284.599', '335.1', '165', '110.929', '1950', '61.187')
# ('96.2', '328.975', '209.9', '309.9', '112.075', '1951', '63.221')
# ('98.1', '346.999', '193.2', '359.4', '113.27', '1952', '63.639')
# ('99', '365.385', '187', '354.7', '115.094', '1953', '64.989')
# ('100', '363.112', '357.8', '335', '116.219', '1954', '63.761')
# ('101.2', '397.469', '290.4', '304.8', '117.388', '1955', '66.019')
# ('104.6', '419.18', '282.2', '285.7', '118.734', '1956', '67.857')
# ('108.4', '442.769', '293.6', '279.8', '120.445', '1957', '68.169')
# ('110.8', '444.546', '468.1', '263.7', '121.95', '1958', '66.513')
# ('112.6', '482.704', '381.3', '255.2', '123.366', '1959', '68.655')
# ('114.2', '502.601', '393.1', '251.4', '125.368', '1960', '69.564')
# ...

# %% [markdown]
# > This is a list containing multiple tuples, each tuple is a row in the Table with each element within this tuple being a string.
# We will be executing mathematical operations on these values and hence we need them in numerical format. Each value contains decimal fractions which means the suitable type to convert to is either double or float. In this case we need to convert these values to a float fomat. Head up to the "utils.py" file and set the function convert_to_floats to be able to do so.

# %%
# To-Do convert to an ndarray of floats by calling the function convert_to_floats from the utils file
# make sure to set some requirements in that function before you call it here
print(type(rows))
shape_data=rows.shape
shape_data
#print(rows.flatten())
rows_flatten=rows.flatten()
rows_flatten
##################
#####here imported the converting function directly
def convert_array(data):
  return data.astype(float)
converted_array=convert_array(rows_flatten)
converted_array
data=converted_array
shape_data
#########here used the utils import
data_conv1 = utils.convert_to_floats(rows)
print(data_conv1)
# Out:
# <class 'numpy.ndarray'>
# [[  83.     234.289  235.6    159.     107.608 1947.      60.323]
#  [  88.5    259.426  232.5    145.6    108.632 1948.      61.122]
#  [  88.2    258.054  368.2    161.6    109.773 1949.      60.171]
#  [  89.5    284.599  335.1    165.     110.929 1950.      61.187]
#  [  96.2    328.975  209.9    309.9    112.075 1951.      63.221]
#  [  98.1    346.999  193.2    359.4    113.27  1952.      63.639]
#  [  99.     365.385  187.     354.7    115.094 1953.      64.989]
#  [ 100.     363.112  357.8    335.     116.219 1954.      63.761]
#  [ 101.2    397.469  290.4    304.8    117.388 1955.      66.019]
#  [ 104.6    419.18   282.2    285.7    118.734 1956.      67.857]
#  [ 108.4    442.769  293.6    279.8    120.445 1957.      68.169]
#  [ 110.8    444.546  468.1    263.7    121.95  1958.      66.513]
#  [ 112.6    482.704  381.3    255.2    123.366 1959.      68.655]
#  [ 114.2    502.601  393.1    251.4    125.368 1960.      69.564]
# ...

# %%
# let's check the shape
data.shape
data_reshape=data.reshape(-1,shape_data[1])

data=data_reshape

# %%
# Let's see the format
data
# Out:
# array([[  83.   ,  234.289,  235.6  ,  159.   ,  107.608, 1947.   ,
#           60.323],
#        [  88.5  ,  259.426,  232.5  ,  145.6  ,  108.632, 1948.   ,
#           61.122],
#        [  88.2  ,  258.054,  368.2  ,  161.6  ,  109.773, 1949.   ,
#           60.171],
#        [  89.5  ,  284.599,  335.1  ,  165.   ,  110.929, 1950.   ,
#           61.187],
#        [  96.2  ,  328.975,  209.9  ,  309.9  ,  112.075, 1951.   ,
#           63.221],
#        [  98.1  ,  346.999,  193.2  ,  359.4  ,  113.27 , 1952.   ,
#           63.639],
#        [  99.   ,  365.385,  187.   ,  354.7  ,  115.094, 1953.   ,
#           64.989],
#        [ 100.   ,  363.112,  357.8  ,  335.   ,  116.219, 1954.   ,
#           63.761],
#        [ 101.2  ,  397.469,  290.4  ,  304.8  ,  117.388, 1955.   ,
#           66.019],
#        [ 104.6  ,  419.18 ,  282.2  ,  285.7  ,  118.734, 1956.   ,
#           67.857],
#        [ 108.4  ,  442.769,  293.6  ,  279.8  ,  120.445, 1957.   ,
# ...

# %% [markdown]
# ### 5. Linear Algebra section: <a id='algebra'></a>

# %%
# Let's check if the two variables GNP.deflator and year  are correlated
x, y =  data[:,5],data[:, 0]
print(x)
print(y)
# Out:
# [1947. 1948. 1949. 1950. 1951. 1952. 1953. 1954. 1955. 1956. 1957. 1958.
#  1959. 1960. 1961. 1962.]
# [ 83.   88.5  88.2  89.5  96.2  98.1  99.  100.  101.2 104.6 108.4 110.8
#  112.6 114.2 115.7 116.9]

# %%
pyplot.scatter(x, y)
pyplot.xlabel("Year")
pyplot.ylabel("GNP.deflactor")
pyplot.show()

# %% [markdown]
# > You can clearly see that the two variables: GNP.deflator (y axis) and year (x axis). In other words the GNP.deflactor is increasing throughout the years.
# Under this trend it makes sense that we can fit a line to these data points, a line that can describe this trend. And this is our task for this section.

# %% [markdown]
# #### Explanation:
# Curve fitting aims to find the perfect curve equation for a number of correlated variables. In our example we aim to find the equation for the line that can perfectly fit this point . Such a line should be at minimum distance from all points in average.
#
# Because we are dealing with two variables only, the line's equation should be of the form : y = a*x + b . Which is a typical linear equation.
#
# To acheieve this you will have to :
#
# 1. Head to the file linear_algebra/curve_fiiting.py file.
#
# 2. Set the objective  function's code (function set_objective), objective function is the function that returns the typical shape of our wanted linear equation ( a*x+b), Please delete the "pass" statement and write your code.
#
# 3. Here in this notebook in the cell below, call the function get_results and pass to it  x and y and get back the optimal values of "a" and "b".

# %%
# To-Do get the values of a and b using the get_result function

import sys
#path_linear_algebra="https://github.com/CLA-Data-Science-Bootcamp/prep_unit_project/tree/63c17998b05a8cbbefd739c4d7a385b5fc71daee/linear_algebra"
path_linear_algebra="./prep_unit_project"

sys.path.append(path_linear_algebra)

#import sys
#sys.path.append("./scripts")

#from helpers import greet, add_numbers

from linear_algebra import curve_fitting_2 as cf
#from curve_fitting_2 import set_objective,get_result
a,b = cf.get_result(x, y)
#print(a)
# Out:
# y = 2.24662 * x + -4289.33294

# %%
# plotting the result
from numpy import arange

pyplot.scatter(x, y)
# define a sequence of inputs between the smallest and largest known inputs
x_line = arange(min(x), max(x), 1)
# calculate the output for the range
y_line = cf.set_objective(x_line, a, b)
# create a line plot for the mapping function
pyplot.plot(x_line, y_line, '--', color='red')
pyplot.show()

# %%
###I tried to push the changes from cmd,and gitbash to the repository
###and also tried to find a way to directly add, commit and push the changes to
##the main branch but it does not work
##so I loaded up the changes manually to the repo
###I also changed the file names, and changed the references in the code###
###I know this is not best practise....

###use git commands inside of jupyter tests
##clone the repository
#!git clone https://github.com/ronalddillner3-cyber/prep_unit_project.git
###get status of the repository
# !git status
##define notebook for push
#!git experiment_completed_new_final.ipynb
# !git /content/prep_unit_project/experiment.ipynb
##commit changes
#!git commit -m "Updated analysis notebook Dillner"
#####push the changes/notebook into gihub repo
#!git push origin main


####git commands to directly push changes within notebook to github
# Install Git if not already available
#!apt-get install git -y

# Configure Git (replace with your info)
#!git config --global user.email "ronalddillner3@googlemail.com"
#!git config --global user.name "ronalddillner3-cyber"

# Clone your repo (HTTPS or SSH)
#!git clone https://github.com/ronalddillner3-cyber/prep_unit_project.git
#%cd prep_unit_project

# Copy your notebook into the repo
#!cp /content/prep_unit_project/experiment_completed_new_final.ipynb .

# Stage, commit, and push
#!git add experiment_completed_new_final.ipynb
#!git commit -m "Add notebook from Colab with changes 1"
#!git push https://github.com/ronalddillner3-cyber/prep_unit_project.git main

##token
# token="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"


# !pip install PyGithub

# from github import Github
# import base64

# # Authenticate with a personal access token
# g = Github(token)
# repo = g.get_user().get_repo("prep_unit_project")

# # Read notebook content
# with open("/content/prep_unit_project/experiment_completed_new_final.ipynb", "rb") as f:
#     content = f.read()

# # Create or update file in repo
# repo.create_file(
#     path="experiment_completed_new_final.ipynb",
#     message="Upload notebook from Colab",
#     content=base64.b64encode(content).decode(),
#     branch="main"
# )
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# git: '/content/prep_unit_project/experiment.ipynb' is not a git command. See 'git --help'.
# ...
# /tmp/ipykernel_26787/2514931562.py:45: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(token)
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# /tmp/ipykernel_26787/2514931562.py in <cell line: 0>()
#      51
#      52 # Create or update file in repo
# ---> 53 repo.create_file(
#      54     path="experiment_completed_new_final.ipynb",
#      55     message="Upload notebook from Colab",
#
# /usr/local/lib/python3.12/dist-packages/github/Repository.py in create_file(self, path, message, content, branch, committer, author)
#    2782             put_parameters["committer"] = committer._identity
#    2783
# ...

# %% [markdown]
# > yohooo ! It's indeed working!!!

# %% [markdown]
# # Final thoughts :
# This curve fitting process can have many use cases within the machine learning workflow.
#
# A curve fitting can be used as a way to fill in missing values. Datasets aren't always clean. In fact in 90% of the cases we need to do some pre-processing and cleaning for the data before using it in any analysis. In many cases, this cleaning can include filling the missing values, in other words you have some data points with some missing values for some  features, if we know that we have a "model" a curve that is supposed to model the trend(or correlation between two of our existing features we can use it to infer these missing values. So as a result Curve fitting can be used in the data cleaning step of the workflow.
#
# Another use case, is when the curve fitting is our end goal, Thus we are cleaning and modeling because the end objective is to have such an equation, in this case the curve fitting is the heart of the Machine learning project.
